# %%
import sys
import os
# Thêm thư mục gốc của project vào sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from utils.api_client import RAGAPIClient
# Initialize API client
api_client = RAGAPIClient(base_url="http://localhost:8000")

# Check if API is available
if not api_client.check_health():
    print("⚠️ RAG API is not available at http://localhost:8000")
    print("Please start the RAG service first!")
else:
    print("✅ RAG API is available")
# Out:
# 2025-11-13 12:22:08.350 | INFO     | utils.api_client:__init__:28 - Initialized RAG API Client: http://localhost:8000/api/v1
# ✅ RAG API is available

# %%
import json
file_path = "../data/questions.json"

# Đọc file JSON
with open(file_path, "r", encoding="utf-8") as f:
    questions = json.load(f)

# In ra dữ liệu đã load
print(questions)
# Out:
# [{'question_id': 'Q001', 'question': 'Ngành Kỹ thuật Máy tính có thể làm những công việc gì sau khi tốt nghiệp?'}, {'question_id': 'Q002', 'question': 'Chương trình Kỹ thuật Máy tính có bao nhiêu tín chỉ tổng cộng, phân bổ giữa các khối kiến thức chính như thế nào?'}, {'question_id': 'Q003', 'question': 'Sinh viên mới vào học nên theo thứ tự học những môn nền tảng nào trong hai năm đầu để có nền tảng vững về lập trình, cấu trúc dữ liệu, hệ điều hành và kiến trúc máy tính?'}, {'question_id': 'Q004', 'question': 'Nếu em muốn theo hướng Hệ thống nhúng/IoT thì yêu cầu học những môn gì và kế hoạch ra sao?'}, {'question_id': 'Q005', 'question': 'Ngành này có những định hướng chuyên ngành tự chọn nào?'}, {'question_id': 'Q006', 'question': "Môn 'Thực tập doanh nghiệp' (CE502) có bắt buộc không? Có thể đổi sang hình thức khác không?"}, {'question_id': 'Q007', 'question': 'Nếu em muốn theo hướng Hệ thống nhúng/IoT hoặc hướng Robotics & AI thì nên chọn những môn tự chọn nào, và mỗi hướng yêu cầu kỹ năng, nền tảng khác nhau ra sao?'}, {'question_id': 'Q008', 'question': 'Chương trình có những phương thức tốt nghiệp nào? Thời lượng/ tín chỉ và điều kiện tham gia mỗi phương thức ra sao?'}, {'question_id': 'Q009', 'question': 'Nếu một sinh viên muốn thay Khóa luận (CE505) bằng Đồ án tốt nghiệp tại doanh nghiệp (CE507): (a) họ cần tích lũy bao nhiêu tín chỉ thay thế, (b) thời gian thực hiện tối thiểu là bao lâu, (c) cần có những điều kiện/giấy tờ gì để đăng ký, và (d) mô tả checklist hướng dẫn từ việc tìm doanh nghiệp đến nộp báo cáo tốt nghiệp.'}, {'question_id': 'Q010', 'question': 'Ngành Kỹ thuật máy tính chương trình đại trà học tiếng Anh bao nhiêu tín chỉ?'}]

# %%
rag_responses = []
# Generate answers for first N test cases
for i, tc in enumerate(questions):
    question_id = tc['question_id']
    question = tc['question']
    print(f"[{question_id}] Generating answer for: {question[:50]}...")
    
    try:
        # Call RAG API
        response = api_client.ask_question(question)
        formatted = api_client.format_response(response)
        
        # Store result
        rag_responses.append({
            'question_id':question_id,
            'question': question,
            'answer': formatted['answer'],
            'contexts': formatted['sources'],
            'processing_time': formatted['processing_time']
        })
        
        print(f"  ✅ Got answer ({len(formatted['answer'])} chars)")
        
    except Exception as e:
        print(f"  ❌ Error: {e}")
        rag_responses.append({
            'question_id': tc['id'],
            'question': question,
            'answer': '',
            'contexts': [],
            'error': str(e)
        })

print(f"\n✅ Generated {len([r for r in rag_responses if r.get('answer')])} answers")
# Out:
# 2025-11-13 12:33:07.459 | INFO     | utils.api_client:ask_question:50 - Asking question: Ngành Kỹ thuật Máy tính có thể làm những công việc...
# [Q001] Generating answer for: Ngành Kỹ thuật Máy tính có thể làm những công việc...
# 2025-11-13 12:33:24.839 | INFO     | utils.api_client:ask_question:59 - Got response in 17.36s
# 2025-11-13 12:33:24.841 | INFO     | utils.api_client:ask_question:50 - Asking question: Chương trình Kỹ thuật Máy tính có bao nhiêu tín ch...
#   ✅ Got answer (650 chars)
# [Q002] Generating answer for: Chương trình Kỹ thuật Máy tính có bao nhiêu tín ch...
# 2025-11-13 12:33:35.591 | INFO     | utils.api_client:ask_question:59 - Got response in 10.74s
# 2025-11-13 12:33:35.592 | INFO     | utils.api_client:ask_question:50 - Asking question: Sinh viên mới vào học nên theo thứ tự học những mô...
#   ✅ Got answer (52 chars)
# [Q003] Generating answer for: Sinh viên mới vào học nên theo thứ tự học những mô...
# 2025-11-13 12:33:52.631 | INFO     | utils.api_client:ask_question:59 - Got response in 17.02s
# 2025-11-13 12:33:52.632 | INFO     | utils.api_client:ask_question:50 - Asking question: Nếu em muốn theo hướng Hệ thống nhúng/IoT thì yêu ...
#   ✅ Got answer (561 chars)
# [Q004] Generating answer for: Nếu em muốn theo hướng Hệ thống nhúng/IoT thì yêu ...
# 2025-11-13 12:34:13.819 | INFO     | utils.api_client:ask_question:59 - Got response in 21.18s
# 2025-11-13 12:34:13.819 | INFO     | utils.api_client:ask_question:50 - Asking question: Ngành này có những định hướng chuyên ngành tự chọn...
#   ✅ Got answer (611 chars)
# [Q005] Generating answer for: Ngành này có những định hướng chuyên ngành tự chọn...
# 2025-11-13 12:34:29.959 | INFO     | utils.api_client:ask_question:59 - Got response in 16.13s
# 2025-11-13 12:34:29.959 | INFO     | utils.api_client:ask_question:50 - Asking question: Môn 'Thực tập doanh nghiệp' (CE502) có bắt buộc kh...
#   ✅ Got answer (534 chars)
# [Q006] Generating answer for: Môn 'Thực tập doanh nghiệp' (CE502) có bắt buộc kh...
# 2025-11-13 12:34:45.305 | INFO     | utils.api_client:ask_question:59 - Got response in 15.33s
# 2025-11-13 12:34:45.306 | INFO     | utils.api_client:ask_question:50 - Asking question: Nếu em muốn theo hướng Hệ thống nhúng/IoT hoặc hướ...
#   ✅ Got answer (426 chars)
# [Q007] Generating answer for: Nếu em muốn theo hướng Hệ thống nhúng/IoT hoặc hướ...
# 2025-11-13 12:35:14.189 | INFO     | utils.api_client:ask_question:59 - Got response in 28.87s
# 2025-11-13 12:35:14.191 | INFO     | utils.api_client:ask_question:50 - Asking question: Chương trình có những phương thức tốt nghiệp nào? ...
#   ✅ Got answer (2022 chars)
# [Q008] Generating answer for: Chương trình có những phương thức tốt nghiệp nào? ...
# 2025-11-13 12:35:25.381 | INFO     | utils.api_client:ask_question:59 - Got response in 11.18s
# 2025-11-13 12:35:25.381 | INFO     | utils.api_client:ask_question:50 - Asking question: Nếu một sinh viên muốn thay Khóa luận (CE505) bằng...
#   ✅ Got answer (52 chars)
# [Q009] Generating answer for: Nếu một sinh viên muốn thay Khóa luận (CE505) bằng...
# 2025-11-13 12:35:51.250 | INFO     | utils.api_client:ask_question:59 - Got response in 25.86s
# 2025-11-13 12:35:51.252 | INFO     | utils.api_client:ask_question:50 - Asking question: Ngành Kỹ thuật máy tính chương trình đại trà học t...
#   ✅ Got answer (1321 chars)
# [Q010] Generating answer for: Ngành Kỹ thuật máy tính chương trình đại trà học t...
# 2025-11-13 12:36:01.089 | INFO     | utils.api_client:ask_question:59 - Got response in 9.82s
#   ✅ Got answer (52 chars)
#
# ✅ Generated 10 answers

# %%
rag_responses
# Out:
# [{'testcase_id': {'Q001'},
#   'question': 'Ngành Kỹ thuật Máy tính có thể làm những công việc gì sau khi tốt nghiệp?',
#   'answer': 'Dựa trên các tài liệu được cung cấp, sinh viên tốt nghiệp ngành Cử nhân Công nghệ Thông tin có thể làm việc trong nhiều phạm vi và lĩnh vực khác nhau, bao gồm:\n\n| Công việc sau tốt nghiệp |\n|---|\n| Tham mưu, tư vấn |\n| Tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT |\n| Nghiên cứu phát triển và ứng dụng công nghệ thông tin |\n\n**Lưu ý:**  Các tài liệu cung cấp thông tin chung về khả năng làm việc sau tốt nghiệp, không chi tiết về các vị trí cụ thể.',
#   'contexts': [{'score': 13.901946,
#     'doc_id': 'd3f2c2f8-a16a-4d6b-a53c-d6157afce5d4',
#     'chunk_index': 13,
#     'content': 'Sinh viên tốt nghiệp Chương trình đào tạo Cử nhân chính quy ngành Công nghệ Thông tin Việt – Nhật có khả năng làm việc ở những phạm vi và lĩnh vực khác nhau như:',
#     'title': 'Cử Nhân Công Nghệ Thông Tin Nhật - 1.2. Vị trí và khả năng làm việc sau tốt nghiệp'},
#    {'score': 11.161114,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin có phẩm chất chính trị tốt, có đạo đức nghề nghiệp, có ý thức trách nhiệm tổ chức, và có sức khỏe tốt; nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. Bên cạnh đó,',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1\\. GIỚI THIỆU CHUNG - 1.1. Mục tiêu đào tạo'},
#    {'score': 10.930084,
#     'doc_id': '87039d84-7ea9-4e8e-877b-5c348c6771e5',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin Văn Bằng Đại Học Thứ 2 - 1.1. Mục tiêu đào tạo'},
#    {'score': 10.926294,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 102,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1.1. Mục tiêu đào tạo'},
#    {'score': 10.875419,
#     'doc_id': '35147017-64b2-4ab5-93ba-1ee01e66836d',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học hoàn thiện các kiến thức, kỹ năng đạt trình độ cử nhân từ cấp độ cao đẳng. Bên',
#     'title': 'Cử nhân Công Nghệ Thông Tin Liên Thông - 1.1. Mục tiêu đào tạo'}],
#   'processing_time': 31.054759979248047},
#  {'testcase_id': {'Q002'},
#   'question': 'Chương trình Kỹ thuật Máy tính có bao nhiêu tín chỉ tổng cộng, phân bổ giữa các khối kiến thức chính như thế nào?',
#   'answer': 'Thông tin này không có trong ngữ cảnh được cung cấp.',
#   'contexts': [{'score': 11.91076,
#     'doc_id': '820a5088-6cfb-41d0-a9ef-6bcd5d0ce9d6',
#     'chunk_index': 26,
#     'content': 'Khối lượng kiến thức toàn khóa gồm 130 tín chỉ được phân bổ như sau:\n**Bảng2. Khối lượng kiến thức toàn khóa**\n|                                                                             |                                                      |                                                                                         |                                |',
#     'title': 'Cử Nhân Hệ thống Thông tin Chương Trình Tiên Tiến - 5. CHƯƠNG TRÌNH ĐÀO TẠO'},
#    {'score': 11.427243,
#     'doc_id': 'd3f2c2f8-a16a-4d6b-a53c-d6157afce5d4',
#     'chunk_index': 48,
#     'content': '**Tổng cộng 44 tín chỉ,**gồm 2 phần sau:\n\\-\xa0**Phần 1: Bắt buộc**\xa0đối với tất cả sinh viên của ngành, nhằm cung cấp kiến thức nền tảng về lập trình, cơ sở dữ liệu, mạng máy tính, phần cứng máy tính.\xa0**Tổng cộng 25 tín chỉ**, gồm các môn học trong bảng sau:\n|                     |                |                                      |        |        |        |\n| ------------------- | -------------- | ------------------------------------ | ------ | ------ | ------ |',
#     'title': 'Cử Nhân Công Nghệ Thông Tin Nhật - 3.4. Khối kiến thức giáo dục chuyên nghiệp - 3.4.1. Nhóm các môn học cơ sở ngành'},
#    {'score': 11.403137,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 36,
#     'content': '**Tổng cộng 70 tín chỉ**.\n#### 3.4.1. Nhóm các môn học cơ sở ngành\n**Tổng cộng 44 tín chỉ,**gồm 2 phần sau\xa0**:**\n\\-\xa0**Phần 1: B**\xa0**ắt buộc**\xa0đối với tất cả sinh viên của ngành, nhằm cung cấp kiến thức nền tảng về lập trình, cơ sở dữ liệu, mạng máy tính, phần cứng máy tính.\xa0**Tổng cộng 25 tín chỉ**\xa0, gồm các môn học trong bảng sau:\n|                     |            |                                      |        |        |        |',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 3\\. CHƯƠNG TRÌNH ĐÀO TẠO - 3.4. Khối kiến thức giáo dục chuyên nghiệp'},
#    {'score': 11.165223,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 126,
#     'content': '![](/sites/daa/files/uploads/vb2_cntt_khung_ct_2024.png)',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 3.2. Phân bố các khối kiến thức'},
#    {'score': 11.038738,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 26,
#     'content': '![](/sites/daa/files/uploads/3.2_cntt_2024.png)',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 3\\. CHƯƠNG TRÌNH ĐÀO TẠO - 3.2. Phân bố các khối kiến thức'}],
#   'processing_time': 11.713074922561646},
#  {'testcase_id': {'Q003'},
#   'question': 'Sinh viên mới vào học nên theo thứ tự học những môn nền tảng nào trong hai năm đầu để có nền tảng vững về lập trình, cấu trúc dữ liệu, hệ điều hành và kiến trúc máy tính?',
#   'answer': 'Dựa trên ngữ cảnh được cung cấp, thông tin cụ thể về thứ tự học các môn nền tảng trong hai năm đầu của chương trình Cử nhân Công nghệ Thông tin không được liệt kê. Tuy nhiên, chúng ta có thể xác định các môn nền tảng quan trọng như sau:\n\n| Môn học                   |\n| ------------------------- |\n| Lập trình (không có tên môn cụ thể) |\n| Cấu trúc dữ liệu (không có tên môn cụ thể) |\n| Hệ điều hành (không có tên môn cụ thể) |\n| Kiến trúc máy tính (không có tên môn cụ thể) |\n\n**Lưu ý:** Ngữ cảnh chỉ cung cấp thông tin về chuẩn đầu ra (CĐR) và các kiến thức chuyên sâu, chứ không liệt kê chi tiết các môn học cụ thể.',
#   'contexts': [{'score': 23.088015,
#     'doc_id': '87039d84-7ea9-4e8e-877b-5c348c6771e5',
#     'chunk_index': 12,
#     'content': 'Sinh viên tốt nghiệp chương trình đào tạo Cử nhân chính quy Văn bằng Đại học thứ 2 ngành Công nghệ thông tin phải đáp ứng các yêu cầu về chuẩn đầu ra (CĐR) sau:\n− (LO1) Nắm vững kiến thức nền tảng về khoa học tự nhiên, khoa học xã hội và hiểu khả năng vận dụng những kiến thức đó vào ngành Công nghệ thông tin và thực tiễn (abet 3.1).\n− (LO2) Nắm vững kiến thức nền tảng và một số kiến thức chuyên sâu của ngành Công nghệ thông tin để ứng dụng vào thực tiễn (abet 3.2, gac 2.b).',
#     'title': 'Cử nhân Công Nghệ Thông Tin Văn Bằng Đại Học Thứ 2 - 1.4. Hình thức và thời gian đào tạo'},
#    {'score': 23.075134,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 113,
#     'content': 'Sinh viên tốt nghiệp chương trình đào tạo Cử nhân chính quy Văn bằng Đại học thứ 2 ngành Công nghệ thông tin phải đáp ứng các yêu cầu về chuẩn đầu ra (CĐR) sau:\n− (LO1) Nắm vững kiến thức nền tảng về khoa học tự nhiên, khoa học xã hội và hiểu khả năng vận dụng những kiến thức đó vào ngành Công nghệ thông tin và thực tiễn (abet 3.1).\n− (LO2) Nắm vững kiến thức nền tảng và một số kiến thức chuyên sâu của ngành Công nghệ thông tin để ứng dụng vào thực tiễn (abet 3.2, gac 2.b).',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1.4. Hình thức và thời gian đào tạo'},
#    {'score': 21.686628,
#     'doc_id': 'd3f2c2f8-a16a-4d6b-a53c-d6157afce5d4',
#     'chunk_index': 18,
#     'content': 'Sinh viên tốt nghiệp chương trình đào tạo Cử nhân chính quy ngành Công nghệ thông tin Việt – Nhật phải đáp ứng các yêu cầu về chuẩn đầu ra (CĐR) sau:\n− (LO1) Nắm vững kiến thức nền tảng về khoa học tự nhiên, khoa học xã hội và hiểu khả năng vận dụng những kiến thức đó vào ngành Công nghệ thông tin và thực tiễn (abet 3.1).\n− (LO2) Nắm vững kiến thức nền tảng và một số kiến thức chuyên sâu của ngành Công nghệ thông tin để ứng dụng vào thực tiễn (abet 3.2, gac 2.b).',
#     'title': 'Cử Nhân Công Nghệ Thông Tin Nhật - 1.3. Hình thức và thời gian đào tạo'},
#    {'score': 20.735432,
#     'doc_id': '820a5088-6cfb-41d0-a9ef-6bcd5d0ce9d6',
#     'chunk_index': 12,
#     'content': '| **2**   | **(LO2)**\xa0**Kiến thức nền tảng và chuyên sâu ngành HTTT**                                                                                          |\n| 2.1     | Kiến thức kiến trúc máy tính                                                                                                                       |\n| 2.2     | Kiến thức hệ điều hành                                                                                                                             |',
#     'title': 'Cử Nhân Hệ thống Thông tin Chương Trình Tiên Tiến - 3\\. Chuẩn đầu ra của chương trình đào tạo'},
#    {'score': 20.230291,
#     'doc_id': '34da3f0a-abb8-4c16-ace4-84963ba93aec',
#     'chunk_index': 5,
#     'content': '| PO1          | Có kiến thức nền tảng vững vàng về khoa học máy tính và chuyên sâu về Trí tuệ nhân tạo.                                                                                                                                                                                          |',
#     'title': 'Cử nhân ngành Trí tuệ Nhân tạo - 1\\. GIỚI THIỆU CHUNG - 1.1 Mục tiêu đào tạo'}],
#   'processing_time': 18.45507025718689},
#  {'testcase_id': {'Q004'},
#   'question': 'Nếu em muốn theo hướng Hệ thống nhúng/IoT thì yêu cầu học những môn gì và kế hoạch ra sao?',
#   'answer': 'Dựa trên ngữ cảnh được cung cấp, sinh viên muốn theo hướng Cử nhân Công nghệ Thông tin - Hệ thống nhúng/IoT sẽ cần học các môn sau:\n\n| Môn học                                  | Mã MH   |\n| ---------------------------------------- | ------- |\n| Chuyên đề thiết kế hệ thống nhúng 1         | CE437   |\n| Chuyên đề thiết kế hệ thống nhúng 2         | CE438   |\n| Chuyên đề thiết kế Robotics và AI 1        | CE441   |\n| Chuyên đề thiết kế Robotics và AI 2        | CE442   |\n\n**Kế hoạch:** Các môn này được mở theo từng học kỳ và cập nhật theo xu hướng phát triển công nghệ.  Sinh viên có thể tham gia các môn học thuộc nhóm tự chọn.',
#   'contexts': [{'score': 14.888536,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 74,
#     'content': '| **Nhóm môn học định hướng Hệ thống nhúng và IoT**        |           |                                                                                                                                         |             |             |     |     |                  |',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.3 Khối kiến thức giáo dục chuyên nghiệp'},
#    {'score': 13.15276,
#     'doc_id': '35147017-64b2-4ab5-93ba-1ee01e66836d',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học hoàn thiện các kiến thức, kỹ năng đạt trình độ cử nhân từ cấp độ cao đẳng. Bên',
#     'title': 'Cử nhân Công Nghệ Thông Tin Liên Thông - 1.1. Mục tiêu đào tạo'},
#    {'score': 12.712208,
#     'doc_id': '87039d84-7ea9-4e8e-877b-5c348c6771e5',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin Văn Bằng Đại Học Thứ 2 - 1.1. Mục tiêu đào tạo'},
#    {'score': 12.701239,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 102,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1.1. Mục tiêu đào tạo'},
#    {'score': 12.494299,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 106,
#     'content': '\\- Các môn học\xa0**Chuyên đề thiết kế hệ thống nhúng 1**\xa0(Mã MH: CE437),\xa0**Chuyên đề thiết kế hệ thống nhúng 2**\xa0(Mã MH: CE438),\xa0**Chuyên đề thiết kế Robotics và AI 1**\xa0(Mã MH: CE441),\xa0**Chuyên đề thiết kế Robotics và AI 2**\xa0(Mã MH: CE442) là các môn học được mở theo từng học kỳ, có nội dung được cập nhật phù hợp với xu thế phát triển công, nhu cầu lao động của xã hội hoặc trang bị thêm kiến thức cần thiết cho sinh viên theo từng định hướng. Sinh viên có thể tham gia các môn học thuộc nhóm tự',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'}],
#   'processing_time': 16.793411254882812},
#  {'testcase_id': {'Q005'},
#   'question': 'Ngành này có những định hướng chuyên ngành tự chọn nào?',
#   'answer': 'Dựa trên các tài liệu được cung cấp, sinh viên Cử nhân Công nghệ Thông tin có thể tự chọn các môn học chuyên ngành tự do để tăng tổng số tín chỉ lên tối đa 16 tín chỉ (3 tín chỉ bắt buộc + 13 tín chỉ tự chọn). Sinh viên có thể chọn các môn học thuộc danh mục 4.4.2.3 và có thể chọn các môn học thuộc cả 02 hướng, không nhất thiết cố định 01 hướng.\n\n| Loại Môn Học           | Số Tín Chỉ (Tối đa) |\n| ----------------------- | ------------------- |\n| Môn Bắt buộc ngành CNTT | 3                   |\n| Môn Tự Chọn            | 13                  |\n| **Tổng**                | **16**              |',
#   'contexts': [{'score': 11.617581,
#     'doc_id': '35147017-64b2-4ab5-93ba-1ee01e66836d',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học hoàn thiện các kiến thức, kỹ năng đạt trình độ cử nhân từ cấp độ cao đẳng. Bên',
#     'title': 'Cử nhân Công Nghệ Thông Tin Liên Thông - 1.1. Mục tiêu đào tạo'},
#    {'score': 11.112916,
#     'doc_id': '87039d84-7ea9-4e8e-877b-5c348c6771e5',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin Văn Bằng Đại Học Thứ 2 - 1.1. Mục tiêu đào tạo'},
#    {'score': 11.106289,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 102,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1.1. Mục tiêu đào tạo'},
#    {'score': 10.053131,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin có phẩm chất chính trị tốt, có đạo đức nghề nghiệp, có ý thức trách nhiệm tổ chức, và có sức khỏe tốt; nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. Bên cạnh đó,',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1\\. GIỚI THIỆU CHUNG - 1.1. Mục tiêu đào tạo'},
#    {'score': 8.842251,
#     'doc_id': '35147017-64b2-4ab5-93ba-1ee01e66836d',
#     'chunk_index': 41,
#     'content': '**Bắt buộc**\xa0đối với sinh viên ngành Công nghệ thông tin (**Tối thiểu 12 tín chỉ**).\nSinh viên được chọn môn học chuyên ngành tự do sao cho\xa0**tổng số tín chỉ**\xa0**³\\*\\***1\\***\\*2.**Trong đó, sinh viên có thể chọn học các môn học thuộc danh mục 4.4.2.3 để\xa0**tích lũy không quá 4**\xa0**tín chỉ\\*\\***.\\*\\*Bao gồm 02 hướng có vai trò như nhau, trong đó có một số môn thuộc 01 hướng sẽ được gom cụm. (Sinh viên có thể chọn các môn học thuộc cả 02 hướng, không nhất thiết cố định 01 hướng).',
#     'title': 'Cử nhân Công Nghệ Thông Tin Liên Thông - 4.4. Khối kiến thức giáo dục chuyên nghiệp - 4.4.2. Nhóm các môn học chuyên ngành'}],
#   'processing_time': 18.91506791114807},
#  {'testcase_id': {'Q006'},
#   'question': "Môn 'Thực tập doanh nghiệp' (CE502) có bắt buộc không? Có thể đổi sang hình thức khác không?",
#   'answer': 'Môn Thực tập doanh nghiệp (CE502) là môn bắt buộc, chiếm 2 tín chỉ (TC) và 0 tín chỉ lý thuyết (LT) và 2 tín chỉ thực hành (TH). Tuy nhiên, sinh viên có thể đổi sang hình thức khác của môn này thông qua việc xét tương đương môn học theo quy định. Cụ thể, sinh viên có thể sử dụng 02 tín chỉ tích lũy từ môn INI01 để xét cho môn CE502.',
#   'contexts': [{'score': 18.394876,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 110,
#     'content': '\\- Đối với môn học\xa0**Thực tập quốc tế**(Mã MH: INI01), sinh viên có thể tham gia các chương trình trao đổi sinh viên quốc tế, chương trình thực tập, dự án nghiên cứu ngắn hạn… do các trường đại học, đơn vị nghiên cứu, doanh nghiệp và chính phủ nước ngoài tổ chức tại các quốc gia khác. Sinh viên có thể sử dụng 02 tín chỉ tích lũy từ môn học INI01 để xét cho môn học tự chọn tự do hoặc môn học Thực tập doanh nghiệp (Mã MH: CE502) trong chương trình đào tạo.',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 16.588839,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 108,
#     'content': '\\- Đối với môn\xa0**Thực tập doanh nghiệp**\xa0(Mã MH: CE502), sinh viên nên ưu tiên chọn thực tập tại các đơn vị đối tác của Khoa KTMT và Trường ĐH CNTT trong\xa0**Phụ lục 2**\xa0.Danh sách các đơn vị đối tác sẽ được cập nhật tùy từng thời điểm tại website Khoa KTMT:\xa0[https://fce.uit.edu.vn/](https://fce.uit.edu.vn/). Tuy nhiên, sinh viên vẫn được phép chọn các doanh nghiệp, cơ sở đào tạo, viện nghiên cứu, phòng thí nghiệm… nằm ngoài danh sách này có hoạt động ngành nghề và nội dung tuyển dụng thực tập',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 16.53427,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 93,
#     'content': '**_Bảng 9: Danh sách các môn học tốt nghiệp bắt buộc_**\n| **STT** | **Mã MH** | **Tên môn học**       | **TC** | **LT** | **TH** |\n| ------- | --------- | --------------------- | ------ | ------ | ------ |\n| 1       | CE502     | Thực tập doanh nghiệp | 2      | 0      | 2      |\n| 2       | CE505     | Khóa luận tốt nghiệp  | 10     | 0      | 10     |\nTổng cộng:\xa0**12**\xa0tín chỉ.',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.4 Khối kiến thức tốt nghiệp'},
#    {'score': 14.373882,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 104,
#     'content': '\\- Đối với các môn học\xa0**Tự chọn tự do,**\xa0sinh viên có thể chọn các môn học thuộc khối kiến thức giáo dục chuyên nghiệp trong các chương trình đào tạo đại học hoặc sau đại học của Trường ĐH CNTT hoặc của các trường đại học thành viên khác trong khối ĐHQG –HCM, hoặc của các trường đại học khác ngoài ĐHQG –HCM mà có ký kết hợp tác với Trường ĐH CNTT, hoặc các chương trình đào tạo kiến thức công nghệ từ doanh nghiệp có hợp tác đào tạo thực tập, kiến tập và hướng dẫn Khóa luận tốt nghiệp với Khoa',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 14.353463,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 146,
#     'content': '| **7**                        | CE502                          | Thực tập doanh nghiệp                                                                                    |               | bắt buộc      | 2           | 0   | 2   |              |             |',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 6\\. KẾ HOẠCH GIẢNG DẠY - 6.2. Kế hoạch giảng dạy theo học kỳ'}],
#   'processing_time': 17.042360067367554},
#  {'testcase_id': {'Q007'},
#   'question': 'Nếu em muốn theo hướng Hệ thống nhúng/IoT hoặc hướng Robotics & AI thì nên chọn những môn tự chọn nào, và mỗi hướng yêu cầu kỹ năng, nền tảng khác nhau ra sao?',
#   'answer': 'Dựa trên ngữ cảnh được cung cấp, sinh viên muốn theo hướng Hệ thống nhúng/IoT hoặc hướng Robotics & AI có thể lựa chọn các môn tự chọn sau:\n\n**1. Hướng Hệ thống nhúng/IoT:**\n\n*   **Môn học cụ thể chưa được liệt kê rõ ràng** trong các tài liệu được cung cấp. Tuy nhiên, sinh viên sẽ được khuyến khích tham gia các môn học thuộc nhóm "Chuyên đề tốt nghiệp định hướng hệ thống nhúng và IoT" (CE510) và “Chuyên đề tốt nghiệp định hướng Robotic và AI” (CE511)\n*   **Kỹ năng và nền tảng cần thiết:**\n    *   Kiến thức về hệ thống nhúng, IoT.\n    *   Kỹ năng thiết kế, lập trình cho hệ thống nhúng.\n    *   Hiểu biết về các cảm biến, bộ điều khiển.\n    *   Kỹ năng làm việc với các phần mềm mô phỏng, lập trình nhúng.\n\n**2. Hướng Robotics & AI:**\n\n*   **Môn học cụ thể chưa được liệt kê rõ ràng** trong các tài liệu được cung cấp. Tuy nhiên, sinh viên sẽ được khuyến khích tham gia các môn học thuộc nhóm "Chuyên đề tốt nghiệp định hướng Robotic và AI" (CE511).\n*   **Kỹ năng và nền tảng cần thiết:**\n    *   Kiến thức về Robotics, AI.\n    *   Kỹ năng lập trình cho robot, AI.\n    *   Hiểu biết về các thuật toán, AI.\n    *   Kỹ năng làm việc với các phần mềm mô phỏng, lập trình robot, AI.\n\n**Lưu ý:** Thông tin chi tiết về các môn tự chọn cụ thể, nội dung và yêu cầu đầu vào chưa được đề cập đầy đủ trong các tài liệu được cung cấp.',
#   'contexts': [{'score': 18.950144,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 115,
#     'content': '\\- Các môn học\xa0**Chuyên đề tốt nghiệp định hướng hệ thống nhúng và IoT**\xa0(Mã MH: CE510) và\xa0**Chuyên đề tốt nghiệp định hướng Robotic và AI**\xa0(Mã MH: CE511) là các môn học bổ sung kiến thức và kỹ năng tốt nghiệp cần thiết cho sinh viên thực hiện Đồ án tốt nghiệp theo các định hướng. Sinh viên có thể tham gia các môn học khác thuộc nhóm tự chọn chuyên ngành (xem Bảng 8), các môn học thuộc khối kiến thức chuyên ngành của các CTĐT ngành KTMT ban hành trước năm 2024 hoặc các môn học mới (được ban',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 16.900126,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 74,
#     'content': '| **Nhóm môn học định hướng Hệ thống nhúng và IoT**        |           |                                                                                                                                         |             |             |     |     |                  |',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.3 Khối kiến thức giáo dục chuyên nghiệp'},
#    {'score': 15.341018,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 106,
#     'content': '\\- Các môn học\xa0**Chuyên đề thiết kế hệ thống nhúng 1**\xa0(Mã MH: CE437),\xa0**Chuyên đề thiết kế hệ thống nhúng 2**\xa0(Mã MH: CE438),\xa0**Chuyên đề thiết kế Robotics và AI 1**\xa0(Mã MH: CE441),\xa0**Chuyên đề thiết kế Robotics và AI 2**\xa0(Mã MH: CE442) là các môn học được mở theo từng học kỳ, có nội dung được cập nhật phù hợp với xu thế phát triển công, nhu cầu lao động của xã hội hoặc trang bị thêm kiến thức cần thiết cho sinh viên theo từng định hướng. Sinh viên có thể tham gia các môn học thuộc nhóm tự',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 12.828518,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 9,
#     'content': 'Những\xa0**trụ cột**\xa0của CNTT bao gồm lập trình, mạng máy tính, giao tiếp người-máy, cơ sở dữ liệu, và hệ thống web, được xây dựng trên một nền tảng kiến thức về các\xa0**nền tảng cơ bản**\xa0của CNTT. Bao quát toàn bộ\xa0**phần nền tảng**\xa0và\xa0**trụ cột**\xa0là những ứng dụng trong CNTT như là Đảm bảo và An ninh Thông tin, ứng dụng, v.v. Tuy không mô tả hết tất cả các khía cạnh của ngành CNTT, nhưng nó sẽ làm rõ mô tả của những mối quan hệ của các thành phần chính trong CNTT.',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1\\. GIỚI THIỆU CHUNG - 1.3. Quan điểm xây dựng chương trình đào tạo'},
#    {'score': 12.811887,
#     'doc_id': '87039d84-7ea9-4e8e-877b-5c348c6771e5',
#     'chunk_index': 10,
#     'content': 'Những\xa0**trụ cột**\xa0của CNTT bao gồm lập trình, mạng máy tính, giao tiếp người-máy, cơ sở dữ liệu, và hệ thống web, được xây dựng trên một nền tảng kiến thức về các\xa0**nền tảng cơ bản**\xa0của CNTT. Bao quát toàn bộ\xa0**phần nền tảng**\xa0và\xa0**trụ cột**\xa0là những ứng dụng trong CNTT như là Đảm bảo và An ninh Thông tin, ứng dụng, v.v. Tuy không mô tả hết tất cả các khía cạnh của ngành CNTT, nhưng nó sẽ làm rõ mô tả của những mối quan hệ của các thành phần chính trong CNTT.',
#     'title': 'Cử nhân Công Nghệ Thông Tin Văn Bằng Đại Học Thứ 2 - 1.3. Quan điểm xây dựng chương trình đào tạo'}],
#   'processing_time': 25.625536918640137},
#  {'testcase_id': {'Q008'},
#   'question': 'Chương trình có những phương thức tốt nghiệp nào? Thời lượng/ tín chỉ và điều kiện tham gia mỗi phương thức ra sao?',
#   'answer': 'Thông tin này không có trong ngữ cảnh được cung cấp. Ngữ cảnh chỉ tập trung vào mục tiêu đào tạo của chương trình Cử nhân Công nghệ Thông tin, chứ không cung cấp thông tin về phương thức tốt nghiệp, thời lượng/tín chỉ và điều kiện tham gia của mỗi phương thức.',
#   'contexts': [{'score': 15.400813,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin có phẩm chất chính trị tốt, có đạo đức nghề nghiệp, có ý thức trách nhiệm tổ chức, và có sức khỏe tốt; nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. Bên cạnh đó,',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1\\. GIỚI THIỆU CHUNG - 1.1. Mục tiêu đào tạo'},
#    {'score': 14.796805,
#     'doc_id': '35147017-64b2-4ab5-93ba-1ee01e66836d',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học hoàn thiện các kiến thức, kỹ năng đạt trình độ cử nhân từ cấp độ cao đẳng. Bên',
#     'title': 'Cử nhân Công Nghệ Thông Tin Liên Thông - 1.1. Mục tiêu đào tạo'},
#    {'score': 14.690481,
#     'doc_id': 'd3f2c2f8-a16a-4d6b-a53c-d6157afce5d4',
#     'chunk_index': 1,
#     'content': 'Chương trình Công nghệ Thông tin Việt – Nhật đào tạo những cử nhân có phẩm chất chính trị tốt, có đạo đức nghề nghiệp, có ý thức trách nhiệm tổ chức, và có sức khỏe tốt; nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin; đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. Bên cạnh đó, trên cơ sở các kiến thức được',
#     'title': 'Cử Nhân Công Nghệ Thông Tin Nhật - 1.1. Mục tiêu đào tạo'},
#    {'score': 14.592874,
#     'doc_id': '87039d84-7ea9-4e8e-877b-5c348c6771e5',
#     'chunk_index': 1,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin Văn Bằng Đại Học Thứ 2 - 1.1. Mục tiêu đào tạo'},
#    {'score': 14.582238,
#     'doc_id': '58913548-9171-48f7-bac1-dd378521487f',
#     'chunk_index': 102,
#     'content': 'Chương trình Cử nhân Công nghệ Thông tin đào tạo những cử nhân ngành Công nghệ thông tin nắm vững các kiến thức cơ bản và chuyên môn sâu về công nghệ thông tin (CNTT); đáp ứng các yêu cầu về nghiên cứu phát triển và ứng dụng công nghệ thông tin của xã hội; có năng lực tham mưu, tư vấn và có khả năng tổ chức thực hiện nhiệm vụ với tư cách của một chuyên viên trong lĩnh vực CNTT. CTĐT định hướng đến việc giúp người học thay đổi mục tiêu nghề nghiệp, có khả năng vận dụng các kiến thức CNTT ứng dụng',
#     'title': 'Cử nhân Công Nghệ Thông Tin - 1.1. Mục tiêu đào tạo'}],
#   'processing_time': 14.844165086746216},
#  {'testcase_id': {'Q009'},
#   'question': 'Nếu một sinh viên muốn thay Khóa luận (CE505) bằng Đồ án tốt nghiệp tại doanh nghiệp (CE507): (a) họ cần tích lũy bao nhiêu tín chỉ thay thế, (b) thời gian thực hiện tối thiểu là bao lâu, (c) cần có những điều kiện/giấy tờ gì để đăng ký, và (d) mô tả checklist hướng dẫn từ việc tìm doanh nghiệp đến nộp báo cáo tốt nghiệp.',
#   'answer': 'Dựa trên ngữ cảnh được cung cấp, đây là câu trả lời cho câu hỏi của bạn:\n\n**Trả lời:**\n\nDưới đây là thông tin chi tiết về việc thay thế Khóa luận tốt nghiệp (CE505) bằng Đồ án tốt nghiệp tại doanh nghiệp (CE507), theo các yêu cầu đã được xác định:\n\n** (a) Số lượng tín chỉ thay thế:**\n\n*   Sinh viên cần tích lũy **10 tín chỉ** thay thế cho môn Khóa luận tốt nghiệp (CE505) bằng cách thực hiện Đồ án tốt nghiệp tại doanh nghiệp (CE507).\n\n** (b) Thời gian thực hiện tối thiểu:**\n\n*   Thời gian thực hiện tối thiểu của môn học Đồ án tốt nghiệp tại doanh nghiệp là **4-6 tháng**, được khuyến khích là **6 tháng**.\n\n** (c) Điều kiện/Giấy tờ cần thiết để đăng ký:**\n\n*   Sinh viên cần chọn các công ty có ký kết hợp tác chính thức với Khoa KTMT hoặc Trường ĐH CNTT.\n*   Sinh viên cần tham vấn ý kiến trực tiếp từ cố vấn học tập hoặc giáo vụ khoa.\n*   Sinh viên cần có kế hoạch đăng ký môn Thực tập doanh nghiệp và Đồ án tốt nghiệp tại doanh nghiệp trong cùng một học kỳ hoặc hai học kỳ liên tiếp.\n\n** (d) Checklist hướng dẫn từ việc tìm doanh nghiệp đến nộp báo cáo tốt nghiệp:**\n\n1.  **Tìm kiếm và lựa chọn doanh nghiệp:** Tham khảo danh sách các đối tác của Khoa KTMT và Trường ĐH CNTT (Phụ lục 2).\n2.  **Tham vấn cố vấn học tập/giáo vụ:** Thảo luận về kế hoạch dự án với cố vấn học tập hoặc giáo vụ khoa.\n3.  **Đăng ký môn học:** Đăng ký môn Đồ án tốt nghiệp tại phòng đào tạo hoặc phòng chức năng của khoa.\n4.  **Thực hiện dự án tại doanh nghiệp:** Thực hiện dự án theo kế hoạch đã thống nhất với doanh nghiệp và cố vấn.\n5.  **Báo cáo tiến độ:** Báo cáo tiến độ thực hiện dự án định kỳ cho cố vấn và giáo vụ khoa.\n6.  **Nộp báo cáo tốt nghiệp:** Chuẩn bị và nộp báo cáo hoàn chỉnh theo yêu cầu của khoa.\n\n**Lưu ý:** Thông tin chi tiết và cập nhật nhất bạn nên tìm thấy trên website chính thức của Trường Đại học Công nghệ Thông tin (UIT) hoặc liên hệ trực tiếp với Khoa Kỹ thuật Máy tính.',
#   'contexts': [{'score': 30.586143,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 111,
#     'content': '\\- Môn học**Đồ án**\xa0**tốt nghiệp tại doanh nghiệp**\xa0(Mã MH: CE507) được xét tương đương là phương thức hai để thay thế môn học Khóa luận tốt nghiệp (Mã MH: CE505) (theo Quyết định số 697/QĐ-ĐHCNTT ngày 12/7/2024 về môn học Đồ án tốt nghiệp tại doanh nghiệp). Khi đăng ký nơi thực hiện cho môn học này, sinh viên cần chọn các công ty có ký kết hợp tác chính thức với Khoa KTMT hoặc Trường ĐH CNTT và cần tham vấn ý kiến trực tiếp từ cố vấn học tập hoặc giáo vụ khoa. Sinh viên có thể tham khảo danh',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 30.159548,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 95,
#     'content': '\\- Trong trường hợp sinh viên đủ điều kiện làm Khóa luận tốt nghiệp nhưng không muốn làm, hoặc sinh viên không đủ điều kiện làm Khóa luận tốt nghiệp thì sinh viên có thể đăng ký môn học hoặc nhóm môn học thay thế cho Khóa luận tốt nghiệp trong\xa0**_Bảng 10_**\xa0để tích lũy 10 tín chỉ.\n**_Bảng 10: Danh sách nhóm môn học thay thế Khóa luận tốt nghiệp_**',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.4 Khối kiến thức tốt nghiệp'},
#    {'score': 30.138653,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 112,
#     'content': 'giáo vụ khoa. Sinh viên có thể tham khảo danh sách các đối tác của Khoa KTMT và Trường ĐH CNTT trong\xa0**Phụ lục 2**\xa0. Thời gian thực hiện môn học này tại doanh nghiệp là từ 4-6 tháng (khuyến khích 6 tháng) để đảm bảo số giờ tối thiểu theo quy định. Sinh viên nên có kế hoạch đăng ký môn Thực tập doanh nghiệp và Đồ án tốt nghiệp tại doanh nghiệp trong cùng một học kỳ hoặc hai học kỳ liên tiếp để thuận tiện cho việc thực hiện.',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'},
#    {'score': 29.768862,
#     'doc_id': '34da3f0a-abb8-4c16-ace4-84963ba93aec',
#     'chunk_index': 117,
#     'content': '● Sinh viên tích lũy tối thiểu 10 tín chỉ cho khối kiến thức tốt nghiệp.\n● Sinh viên được chọn:\n○ Hoặc, thực hiện Khóa luận tốt nghiệp (KLTN) 10 tín chỉ nếu sinh viên đủ điều kiện làm khóa luận tốt nghiệp theo qui chế của trường.\n○ Hoặc, thực hiện Đồ án tốt nghiệp tại doanh nghiệp 10 tín chỉ.\n○ Hoặc, thực hiện Đồ án tốt nghiệp 6 tín chỉ và học một trong các môn chuyên đề tốt nghiệp (4 tín chỉ) để đạt tối thiểu 10 tín chỉ.',
#     'title': 'Cử nhân ngành Trí tuệ Nhân tạo - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.4 Khối kiến thức tốt nghiệp'},
#    {'score': 27.048512,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 113,
#     'content': '\\- Môn học\xa0**Đồ án tốt nghiệp**\xa0(Mã MH: CE508) được xem như phương thức ba của môn học Khóa luận tốt nghiệp (Mã MH: CE505). Sinh viên phải học môn Đồ án tốt nghiệp kết hợp với tối thiểu một môn chuyên đề tốt nghiệp (Mã MH: CE510 hoặc CE511) để tích lũy đủ tối thiểu 10 tín chỉ thay thế cho Khóa luận tốt nghiệp. Ngoài ra, môn học Đồ án tốt nghiệp được xét tương đương (hay thay thế) cho hai môn học gồm tự chọn chuyên ngành và đồ án chuyên ngành (tổng cộng 06 tín chỉ) trong nhóm môn học chuyên đề',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 5\\. CHƯƠNG TRÌNH ĐÀO TẠO - 5.5 Mô tả các môn học mới và việc xét tương đương môn học'}],
#   'processing_time': 29.82515835762024},
#  {'testcase_id': {'Q010'},
#   'question': 'Ngành Kỹ thuật máy tính chương trình đại trà học tiếng Anh bao nhiêu tín chỉ?',
#   'answer': 'Thông tin này không có trong ngữ cảnh được cung cấp.',
#   'contexts': [{'score': 12.182893,
#     'doc_id': '34da3f0a-abb8-4c16-ace4-84963ba93aec',
#     'chunk_index': 19,
#     'content': 'Chương trình đào tạo Cử nhân chính quy ngành Khoa học máy tính được áp dụng theo quy chế, quy định đào tạo đại học hiện hành của Trường Đại học Công nghệ Thông tin.',
#     'title': 'Cử nhân ngành Trí tuệ Nhân tạo - 3\\. QUY CHẾ ĐÀO TẠO'},
#    {'score': 12.024221,
#     'doc_id': 'd3f2c2f8-a16a-4d6b-a53c-d6157afce5d4',
#     'chunk_index': 26,
#     'content': 'Sinh viên tốt nghiệp chương trình này phải hoàn thành các môn học tiếng Nhật trong chương trình đào tạo và có chứng chỉ tiếng Nhật theo quy định đào tạo ngoại ngữ hiện hành của Trường Đại học Công nghệ Thông tin.\n# 3\\. CHƯƠNG TRÌNH ĐÀO TẠO',
#     'title': 'Cử Nhân Công Nghệ Thông Tin Nhật - 1.3. Hình thức và thời gian đào tạo'},
#    {'score': 11.2744665,
#     'doc_id': '34da3f0a-abb8-4c16-ace4-84963ba93aec',
#     'chunk_index': 16,
#     'content': '\\- Tên ngành đào tạo:\no Tiếng Việt: Trí tuệ nhân tạo\no Tiếng Anh: Artificial Intelligence\n\\- Mã ngành đào tạo: 7480107\n\\- Trình độ đào tạo: Đại học.\n\\- Loại hình đào tạo: Chính quy tập trung.\n\\- Thời gian đào tạo: 3.5 năm (gồm 7 học kỳ chính thức).\n\\- Số tín chỉ đào tạo: Tối thiểu\xa0**128**\xa0tín chỉ (bao gồm cả ngoại ngữ)\n\\- Tên văn bằng sau khi tốt nghiệp:\no Tiếng Việt: Cử nhân Trí tuệ nhân tạo\no Tiếng Anh: Bachelor of Science in Artificial Intelligence',
#     'title': 'Cử nhân ngành Trí tuệ Nhân tạo - 1\\. GIỚI THIỆU CHUNG - 1.4 Hình thức và thời gian đào tạo'},
#    {'score': 11.153012,
#     'doc_id': 'd3f2c2f8-a16a-4d6b-a53c-d6157afce5d4',
#     'chunk_index': 43,
#     'content': '**Lưu ý**: Số tín chỉ của các học phần tiếng Nhật 1, 2, 3 và 4 được tính vào số tín chỉ của chương trình đào tạo (20 TC) và các học phần tiếng Nhật 5, 6, 7 và 8 không tính vào số tín chỉ của chương trình đào tạo.\nDanh sách các học phần tiếng Nhật dự kiến giảng dạy trong chương trình đào tạo như sau:\n| **STT**             | **Mã môn học** | **Tên môn học**                                           | **TC** | **LT** | **TH** |',
#     'title': 'Cử Nhân Công Nghệ Thông Tin Nhật - 3.3. Khối kiến thức giáo dục đại cương'},
#    {'score': 10.268591,
#     'doc_id': '4ef392b5-6bab-4450-a24e-66369421a063',
#     'chunk_index': 11,
#     'content': '\\- Chương trình đào tạo được thiết kế tinh gọn, nội dung phù hợp, linh động, tạo sự chủ động cho người học và đảm bảo sự thuận lợi cho quá trình vận hành chương trình đào tạo giữa các khóa tuyển sinh.\n\\- Chương trình đào tạo mang tính liên ngành và tính ứng dụng cao, phù hợp với nhu cầu nhân lực công nghệ thông tin của xã hội, tiếp cận với trình độ của các trường đại học trong và ngoài nước trong lĩnh vực KTMT.',
#     'title': 'Cử nhân ngành Kỹ thuật Máy tính - 1\\. GIỚI THIỆU CHUNG - 1.3 Quan điểm xây dựng chương trình đào tạo'}],
#   'processing_time': 11.410006046295166}]

# %%
def convert_sets(obj):
    if isinstance(obj, set):
        return list(obj)
    elif isinstance(obj, dict):
        return {k: convert_sets(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [convert_sets(x) for x in obj]
    else:
        return obj

rag_responses_jsonable = convert_sets(rag_responses)

# %%
output_path = "../data/rag_results.json"

# Ghi ra JSON với định dạng đẹp
with open(output_path, "w", encoding="utf-8-sig") as f:
    json.dump(rag_responses, f, ensure_ascii=False, indent=2)

print(f"✅ Saved {len(rag_responses)} responses to {output_path}")
# Out:
# ✅ Saved 10 responses to ../data/rag_results.json

# %%
import utils.convert_results_to_csv as convert_utils

# %%
convert_utils.convert_json_to_csv(
    json_file="../data/rag_results.json",
    csv_file="../data/rag_results.csv"
)
# Out:
# ✅ Converted 10 queries to ../data/rag_results.csv
#    Total rows: 50

# %%
import json
import csv
file_path = "../data/questions.json"

# Đọc file JSON
with open(file_path, "r", encoding="utf-8") as f:
    questions = json.load(f)

with open("questions.csv", "w", newline="", encoding="utf-8-sig") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["query"])
    for row in questions:
        writer.writerow([row["question"]])
